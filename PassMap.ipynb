# %%
import pandas as pd
from mplsoccer import Pitch,Sbopen
import numpy as np
import matplotlib.pyplot as plt

# %%
parser= Sbopen()

# %%
df, related, freeze, tactics = parser.event(3749246)

# %%
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'counterpress', 'outcome_id', 'outcome_name', 'pass_assisted_shot_id',
#        'pass_shot_assist', 'shot_statsbomb_xg', 'end_z', 'shot_key_pass_id',
#        'shot_first_time', 'technique_id', 'technique_name',
#        'goalkeeper_position_id', 'goalkeeper_position_name',
#        'foul_won_defensive', 'off_camera', 'pass_switch', 'out',
# ...

# %%
df['substitution_replacement_id']
# Out:
# 4      NaN
# 7      NaN
# 10     NaN
# 13     NaN
# 16     NaN
#         ..
# 3060   NaN
# 3066   NaN
# 3079   NaN
# 3082   NaN
# 3091   NaN
# Name: substitution_replacement_id, Length: 364, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'counterpress', 'outcome_id', 'outcome_name', 'pass_assisted_shot_id',
#        'pass_shot_assist', 'shot_statsbomb_xg', 'end_z', 'shot_key_pass_id',
#        'shot_first_time', 'technique_id', 'technique_name',
#        'goalkeeper_position_id', 'goalkeeper_position_name',
#        'foul_won_defensive', 'off_camera', 'pass_switch', 'out',
# ...

# %%
df = df[df['team_name']=='Arsenal']

# %%
df.head(50)
# Out:
#                                       id  index  period        timestamp  \
# 0   a356c4d4-af2a-44c8-a8bd-6342386333c0      1       1         00:00:00
