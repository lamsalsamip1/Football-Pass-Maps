# %%
# !pip install statsbombpy
# Out:
# ...
#      --------------------------------------- 61.4/61.4 kB 90.9 kB/s eta 0:00:00
# ...
#      --------------------------------------- 57.5/57.5 kB 17.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 60.8/60.8 kB 8.7 kB/s eta 0:00:00
# ...
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.0.0rc9
#     Uninstalling exceptiongroup-1.0.0rc9:
#       Successfully uninstalled exceptiongroup-1.0.0rc9
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lamsa\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lamsa\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
from statsbombpy import sb

# %%
sb.competitions()[competition_name=='La Liga']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 sb.competitions()[competition_name=='La Liga']
#
# NameError: name 'competition_name' is not defined

# %%
sb.matches(competition_id=11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 sb.matches(competition_id=11)
#
# TypeError: matches() missing 1 required positional argument: 'season_id'

# %%
events = sb.events(match_id=69301)
# Out:
# C:\Users\lamsa\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events.head()
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_save_block  \
# 0                            NaN              NaN              NaN
# 1                            NaN              NaN              NaN
# 2                            NaN              NaN              NaN
# 3                            NaN              NaN              NaN
# 4                            NaN              NaN              NaN
#
#   carry_end_location counterpress dribble_outcome  ... shot_technique  \
# ...

# %%
events.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_save_block', 'carry_end_location',
#        'counterpress', 'dribble_outcome', 'dribble_overrun', 'duel_outcome',
#        'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'interception_outcome', 'location', 'match_id', 'minute',
#        'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
#        'pass_backheel', 'pass_body_part', 'pass_cross', 'pass_cut_back',
#        'pass_deflected', 'pass_end_location', 'pass_goal_assist',
# ...

# %%
df=sb.competitions()

# %%
rslt_df = df[df['competition_name']=="Premier League"]

# %%
rslt_df
# Out:
#     competition_id  season_id country_name competition_name  \
# 62               2         27      England   Premier League
# 63               2         44      England   Premier League
#
#    competition_gender  competition_youth  competition_international  \
# 62               male              False                      False
# 63               male              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 62   2015/2016  2023-11-14T11:25:33.476498  2021-06-13T16:17:31.694
# 63   2003/2004  2023-11-14T11:20:59.843499  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 62                None  2023-11-14T11:25:33.476498
# 63                None  2023-11-14T11:20:59.843499

# %%
sb.matches(competition_id=2,season_id=44)
# Out:
#     match_id  match_date      kick_off               competition     season  \
# 0    3749052  2004-02-07  16:00:00.000  England - Premier League  2003/2004
# 1    3749522  2003-12-26  13:00:00.000  England - Premier League  2003/2004
# 2    3749246  2004-03-28  17:05:00.000  England - Premier League  2003/2004
# 3    3749257  2004-05-15  16:00:00.000  England - Premier League  2003/2004
# 4    3749642  2004-02-28  16:00:00.000  England - Premier League  2003/2004
# 5    3749358  2003-08-24  17:05:00.000  England - Premier League  2003/2004
# 6    3749346  2003-11-01  16:00:00.000  England - Premier League  2003/2004
# 7    3749253  2003-10-04  13:30:00.000  England - Premier League  2003/2004
# 8    3749079  2003-10-18  16:00:00.000  England - Premier League  2003/2004
# 9    3749465  2004-03-13  16:00:00.000  England - Premier League  2003/2004
# 10   3749133  2004-01-18  15:00:00.000  England - Premier League  2003/2004
# ...

# %%
sb.matches(competition_id=2,season_id=27)
# Out:
# C:\Users\lamsa\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      match_id  match_date      kick_off               competition     season  \
# 0     3754058  2016-01-02  16:00:00.000  England - Premier League  2015/2016
# 1     3754245  2015-10-17  16:00:00.000  England - Premier League  2015/2016
# 2     3754136  2015-12-19  18:30:00.000  England - Premier League  2015/2016
# 3     3754037  2016-04-30  16:00:00.000  England - Premier League  2015/2016
# 4     3754039  2016-02-13  16:00:00.000  England - Premier League  2015/2016
# ..        ...         ...           ...                       ...        ...
# 375   3754020  2015-08-17  21:00:00.000  England - Premier League  2015/2016
# 376   3754267  2015-08-15  16:00:00.000  England - Premier League  2015/2016
# 377   3754141  2015-08-09  14:30:00.000  England - Premier League  2015/2016
# ...
