# %%
from statsbombpy import sb
import pandas as pd
from mplsoccer import Pitch,Sbopen
import matplotlib.pyplot as plt

# %%
comps = sb.competitions()
comps['competition_name'].unique()
# Out:
# array(['1. Bundesliga', 'African Cup of Nations', 'Champions League',
#        'Copa del Rey', "FA Women's Super League", 'FIFA U20 World Cup',
#        'FIFA World Cup', 'Indian Super league', 'La Liga',
#        'Liga Profesional', 'Ligue 1', 'Major League Soccer',
#        'North American League', 'NWSL', 'Premier League', 'Serie A',
#        'UEFA Euro', 'UEFA Europa League', "UEFA Women's Euro",
#        "Women's World Cup"], dtype=object)

# %%
comps[comps['competition_name']=='FIFA World Cup']
# Out:
#     competition_id  season_id   country_name competition_name  \
# 27              43        106  International   FIFA World Cup
# 28              43          3  International   FIFA World Cup
# 29              43         55  International   FIFA World Cup
# 30              43         54  International   FIFA World Cup
# 31              43         51  International   FIFA World Cup
# 32              43        272  International   FIFA World Cup
# 33              43        270  International   FIFA World Cup
# 34              43        269  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 27               male              False                       True
# 28               male              False                       True
# 29               male              False                       True
# 30               male              False                       True
# 31               male              False                       True
# 32               male              False                       True
# 33               male              False                       True
# 34               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 27        2022  2023-11-05T04:23:26.649917  2023-11-21T15:37:11.589616
# 28        2018  2023-07-24T13:09:34.513519     2021-06-13T16:17:31.694
# 29        1990  2023-06-28T10:58:20.137929     2021-06-12T16:17:31.694
# 30        1986  2023-06-28T11:20:34.252935     2021-06-13T16:17:31.694
# 31        1974  2023-07-17T23:19:58.853207     2021-06-13T16:17:31.694
# 32        1970  2023-07-17T23:24:45.579886                        None
# 33        1962  2023-06-26T10:38:00.323984                        None
# 34        1958  2023-06-26T10:33:08.214831                        None
#
#            match_available_360             match_available
# 27  2023-11-21T15:37:11.589616  2023-11-05T04:23:26.649917
# 28                        None  2023-07-24T13:09:34.513519
# 29                        None  2023-06-28T10:58:20.137929
# 30                        None  2023-06-28T11:20:34.252935
# 31                        None  2023-07-17T23:19:58.853207
# 32                        None  2023-07-17T23:24:45.579886
# 33                        None  2023-06-26T10:38:00.323984
# 34                        None  2023-06-26T10:33:08.214831

# %%
matches = sb.matches(competition_id=43, season_id=106)
matches[matches['home_team']=='Argentina']
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 1    3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 9    3869685  2022-12-18  17:00:00.000  International - FIFA World Cup   2022
# 13   3857289  2022-11-26  21:00:00.000  International - FIFA World Cup   2022
# 19   3869519  2022-12-13  21:00:00.000  International - FIFA World Cup   2022
# 37   3857300  2022-11-22  12:00:00.000  International - FIFA World Cup   2022
#
#     home_team     away_team  home_score  away_score match_status  ...  \
# 1   Argentina     Australia           2           1    available  ...
# 9   Argentina        France           3           3    available  ...
# 13  Argentina        Mexico           2           0    available  ...
# 19  Argentina       Croatia           3           0    available  ...
# 37  Argentina  Saudi Arabia           1           2    available  ...
#
#               last_updated_360 match_week competition_stage  \
# 1   2023-07-30T07:48:51.865595          4       Round of 16
# 9   2023-08-17T15:55:15.164685          7             Final
# 13  2023-06-20T11:57:08.547882          2       Group Stage
# 19  2023-04-26T22:32:37.808359          6       Semi-finals
# 37  2023-06-19T15:59:46.628887          1       Group Stage
#
#                   stadium           referee             home_managers  \
# 1   Ahmad bin Ali Stadium  Szymon Marciniak  Lionel Sebastián Scaloni
# 9          Lusail Stadium  Szymon Marciniak  Lionel Sebastián Scaloni
# 13         Lusail Stadium    Daniele Orsato  Lionel Sebastián Scaloni
# 19         Lusail Stadium    Daniele Orsato  Lionel Sebastián Scaloni
# 37         Lusail Stadium     Slavko Vinčić  Lionel Sebastián Scaloni
#
#              away_managers data_version shot_fidelity_version  \
# 1      Graham James Arnold        1.1.0                     2
# 9         Didier Deschamps        1.1.0                     2
# 13  Gerardo Daniel Martino        1.1.0                     2
# 19            Zlatko Dalić        1.1.0                     2
# 37            Hervé Renard        1.1.0                     2
#
#    xy_fidelity_version
# 1                    2
# 9                    2
# 13                   2
# 19                   2
# 37                   2
#
# [5 rows x 22 columns]

# %%
event = sb.events(match_id=3869685)
event
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                NaN                  NaN                     NaN
# 1      NaN                NaN                  NaN                     NaN
# 2      NaN                NaN                  NaN                     NaN
# 3      NaN                NaN                  NaN                     NaN
# 4      NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 4402   NaN                NaN                  NaN                     NaN
# 4403   NaN                NaN                  NaN                     NaN
# 4404   NaN                NaN                  NaN                     NaN
# 4405   NaN        Yellow Card                  NaN                     NaN
# 4406   NaN        Yellow Card                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                               NaN              NaN             NaN
# 1                               NaN              NaN             NaN
# 2                               NaN              NaN             NaN
# 3                               NaN              NaN             NaN
# 4                               NaN              NaN             NaN
# ...                             ...              ...             ...
# 4402                            NaN              NaN             NaN
# 4403                            NaN              NaN             NaN
# 4404                            NaN              NaN             NaN
# 4405                            NaN              NaN             NaN
# 4406                            NaN              NaN             NaN
#
#      carry_end_location clearance_aerial_won clearance_body_part  ...  \
# 0                   NaN                  NaN                 NaN  ...
# 1                   NaN                  NaN                 NaN  ...
# 2                   NaN                  NaN                 NaN  ...
# 3                   NaN                  NaN                 NaN  ...
# 4                   NaN                  NaN                 NaN  ...
# ...                 ...                  ...                 ...  ...
# 4402                NaN                  NaN                 NaN  ...
# 4403                NaN                  NaN                 NaN  ...
# 4404                NaN                  NaN                 NaN  ...
# 4405                NaN                  NaN                 NaN  ...
# 4406                NaN                  NaN                 NaN  ...
#
#      shot_technique shot_type substitution_outcome substitution_replacement  \
# 0               NaN       NaN                  NaN                      NaN
# 1               NaN       NaN                  NaN                      NaN
# 2               NaN       NaN                  NaN                      NaN
# 3               NaN       NaN                  NaN                      NaN
# 4               NaN       NaN                  NaN                      NaN
# ...             ...       ...                  ...                      ...
# 4402            NaN       NaN                  NaN                      NaN
# 4403            NaN       NaN                  NaN                      NaN
# 4404            NaN       NaN                  NaN                      NaN
# 4405            NaN       NaN                  NaN                      NaN
# 4406            NaN       NaN                  NaN                      NaN
#
#                                                 tactics       team team_id  \
# 0     {'formation': 433, 'lineup': [{'player': {'id'...  Argentina     779
# 1     {'formation': 4231, 'lineup': [{'player': {'id...     France     771
# 2                                                   NaN     France     771
# 3                                                   NaN  Argentina     779
# 4                                                   NaN     France     771
# ...                                                 ...        ...     ...
# 4402                                                NaN  Argentina     779
# 4403                                                NaN     France     771
# 4404                                                NaN  Argentina     779
# 4405                                                NaN     France     771
# 4406                                                NaN  Argentina     779
#
#          timestamp           type under_pressure
# 0     00:00:00.000    Starting XI            NaN
# 1     00:00:00.000    Starting XI            NaN
# 2     00:00:00.000     Half Start            NaN
# 3     00:00:00.000     Half Start            NaN
# 4     00:00:00.000     Half Start            NaN
# ...            ...            ...            ...
# 4402  00:19:07.472       Half End            NaN
# 4403  00:05:58.866       Half End            NaN
# 4404  00:05:58.866       Half End            NaN
# 4405  00:49:35.193  Bad Behaviour            NaN
# 4406  00:04:57.514  Bad Behaviour            NaN
#
# [4407 rows x 92 columns]

# %%
parser = Sbopen()
df, related,freeze,tactics = parser.event(3869685)

# %%
df
# Out:
#                                         id  index  period        timestamp  \
# 0     0584ee21-e3dd-4d9f-95a0-5b5e84be25c3      1       1         00:00:00
# 1     b32679f8-942e-4122-96a2-015caf75e628      2       1         00:00:00
# 2     954f6855-de22-46a2-8d09-6fe94eec2b9b      3       1         00:00:00
# 3     6404a8e8-afaf-489d-b65e-173a237ffed5      4       1         00:00:00
# 4     f651a6c4-55e3-4e0f-a178-59414ba83d6a      5       1  00:00:00.578000
# ...                                    ...    ...     ...              ...
# 4402  071e5f12-a2c3-455d-8129-2b14cb81fad8   4403       5  00:05:10.130000
# 4403  66eaf262-999f-4953-a924-f1b596de4dbf   4404       5  00:05:57.883000
# 4404  14d51627-1f8e-42ec-bf97-74f1f22c5e40   4405       5  00:05:58.379000
# 4405  0e712309-2130-4ad9-ab32-cda2e26c4d0b   4406       5  00:05:58.866000
# 4406  4f66bdf1-2c51-483a-b45a-89b525bc23c0   4407       5  00:05:58.866000
#
#       minute  second  possession  duration  match_id  type_id  ...  \
# 0          0       0           1  0.000000   3869685       35  ...
# 1          0       0           1  0.000000   3869685       35  ...
# 2          0       0           1  0.000000   3869685       18  ...
# 3          0       0           1  0.000000   3869685       18  ...
# 4          0       0           2  0.975702   3869685       30  ...
# ...      ...     ...         ...       ...       ...      ...  ...
# 4402     125      10         254  0.000000   3869685       23  ...
# 4403     125      57         255  0.496009   3869685       16  ...
# 4404     125      58         255  0.000000   3869685       23  ...
# 4405     125      58         255  0.000000   3869685       34  ...
# 4406     125      58         255  0.000000   3869685       34  ...
#
#      foul_committed_card_id  foul_committed_card_name ball_recovery_offensive  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
# ...                     ...                       ...                     ...
# 4402                    NaN                       NaN                     NaN
# 4403                    NaN                       NaN                     NaN
# 4404                    NaN                       NaN                     NaN
# 4405                    NaN                       NaN                     NaN
# 4406                    NaN                       NaN                     NaN
#
#       shot_one_on_one foul_committed_advantage  foul_won_advantage  \
# 0                 NaN                      NaN                 NaN
# 1                 NaN                      NaN                 NaN
# 2                 NaN                      NaN                 NaN
# 3                 NaN                      NaN                 NaN
# 4                 NaN                      NaN                 NaN
# ...               ...                      ...                 ...
# 4402              NaN                      NaN                 NaN
# 4403              NaN                      NaN                 NaN
# 4404              NaN                      NaN                 NaN
# 4405              NaN                      NaN                 NaN
# 4406              NaN                      NaN                 NaN
#
#      block_offensive foul_committed_offensive  bad_behaviour_card_id  \
# 0                NaN                      NaN                    NaN
# 1                NaN                      NaN                    NaN
# 2                NaN                      NaN                    NaN
# 3                NaN                      NaN                    NaN
# 4                NaN                      NaN                    NaN
# ...              ...                      ...                    ...
# 4402             NaN                      NaN                    NaN
# 4403             NaN                      NaN                    NaN
# 4404             NaN                      NaN                    NaN
# 4405             NaN                      NaN                    NaN
# 4406             NaN                      NaN                    NaN
#
#      bad_behaviour_card_name
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 4402                     NaN
# 4403                     NaN
# 4404                     NaN
# 4405                     NaN
# 4406                     NaN
#
# [4407 rows x 76 columns]

# %%
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'sub_type_id', 'sub_type_name',
#        'body_part_id', 'body_part_name', 'x', 'y', 'pass_switch', 'outcome_id',
#        'outcome_name', 'under_pressure', 'off_camera', 'counterpress',
#        'block_deflection', 'pass_deflected', 'foul_won_defensive', 'out',
#        'pass_cross', 'technique_id', 'technique_name', 'aerial_won',
#        'pass_assisted_shot_id', 'pass_shot_assist', 'shot_statsbomb_xg',
#        'end_z', 'shot_key_pass_id', 'goalkeeper_position_id',
#        'goalkeeper_position_name', 'ball_recovery_recovery_failure',
#        'shot_first_time', 'foul_committed_penalty', 'foul_won_penalty',
#        'dribble_nutmeg', 'dribble_overrun', 'pass_goal_assist',
#        'substitution_replacement_id', 'substitution_replacement_name',
#        'foul_committed_card_id', 'foul_committed_card_name',
#        'ball_recovery_offensive', 'shot_one_on_one',
#        'foul_committed_advantage', 'foul_won_advantage', 'block_offensive',
#        'foul_committed_offensive', 'bad_behaviour_card_id',
#        'bad_behaviour_card_name'],
#       dtype='object')

# %%
df = df[df['team_name']=='Argentina']
df
# Out:
#                                         id  index  period        timestamp  \
# 0     0584ee21-e3dd-4d9f-95a0-5b5e84be25c3      1       1         00:00:00
# 3     6404a8e8-afaf-489d-b65e-173a237ffed5      4       1         00:00:00
# 9     5ba6dfab-49f0-4225-bbb6-8b1e27bc729a     10       1  00:00:16.423000
# 11    2be9a9f2-84ab-4935-8fb2-bd497202fa2f     12       1  00:00:17.546000
# 12    a511000a-bb39-4888-80e5-d81cabf8819e     13       1  00:00:17.546000
# ...                                    ...    ...     ...              ...
# 4398  bcc6d4ae-f71c-4566-bf2d-c12f910eb526   4399       5  00:04:16.722000
# 4400  ad6e8237-8cb9-44f4-b9fb-356f066f3b2b   4401       5  00:04:57.514000
# 4402  071e5f12-a2c3-455d-8129-2b14cb81fad8   4403       5  00:05:10.130000
# 4403  66eaf262-999f-4953-a924-f1b596de4dbf   4404       5  00:05:57.883000
# 4406  4f66bdf1-2c51-483a-b45a-89b525bc23c0   4407       5  00:05:58.866000
#
#       minute  second  possession  duration  match_id  type_id  ...  \
# 0          0       0           1  0.000000   3869685       35  ...
# 3          0       0           1  0.000000   3869685       18  ...
# 9          0      16           3  1.123351   3869685       30  ...
# 11         0      17           3       NaN   3869685       42  ...
# 12         0      17           3  1.458978   3869685       43  ...
# ...      ...     ...         ...       ...       ...      ...  ...
# 4398     124      16         253  0.571088   3869685       16  ...
# 4400     124      57         253  0.000000   3869685       24  ...
# 4402     125      10         254  0.000000   3869685       23  ...
# 4403     125      57         255  0.496009   3869685       16  ...
# 4406     125      58         255  0.000000   3869685       34  ...
#
#      foul_committed_card_id  foul_committed_card_name ball_recovery_offensive  \
# 0                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 9                       NaN                       NaN                     NaN
# 11                      NaN                       NaN                     NaN
# 12                      NaN                       NaN                     NaN
# ...                     ...                       ...                     ...
# 4398                    NaN                       NaN                     NaN
# 4400                    NaN                       NaN                     NaN
# 4402                    NaN                       NaN                     NaN
# 4403                    NaN                       NaN                     NaN
# 4406                    NaN                       NaN                     NaN
#
#       shot_one_on_one foul_committed_advantage  foul_won_advantage  \
# 0                 NaN                      NaN                 NaN
# 3                 NaN                      NaN                 NaN
# 9                 NaN                      NaN                 NaN
# 11                NaN                      NaN                 NaN
# 12                NaN                      NaN                 NaN
# ...               ...                      ...                 ...
# 4398              NaN                      NaN                 NaN
# 4400              NaN                      NaN                 NaN
# 4402              NaN                      NaN                 NaN
# 4403              NaN                      NaN                 NaN
# 4406              NaN                      NaN                 NaN
#
#      block_offensive foul_committed_offensive  bad_behaviour_card_id  \
# 0                NaN                      NaN                    NaN
# 3                NaN                      NaN                    NaN
# 9                NaN                      NaN                    NaN
# 11               NaN                      NaN                    NaN
# 12               NaN                      NaN                    NaN
# ...              ...                      ...                    ...
# 4398             NaN                      NaN                    NaN
# 4400             NaN                      NaN                    7.0
# 4402             NaN                      NaN                    NaN
# 4403             NaN                      NaN                    NaN
# 4406             NaN                      NaN                    NaN
#
#      bad_behaviour_card_name
# 0                        NaN
# 3                        NaN
# 9                        NaN
# 11                       NaN
# 12                       NaN
# ...                      ...
# 4398                     NaN
# 4400             Yellow Card
# 4402                     NaN
# 4403                     NaN
# 4406                     NaN
#
# [2372 rows x 76 columns]

# %%
df['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt', 'Carry',
#        'Foul Won', 'Pressure', 'Block', 'Foul Committed', 'Ball Recovery',
#        'Duel', 'Dribble', 'Shot', 'Clearance', 'Dispossessed',
#        'Interception', 'Dribbled Past', 'Injury Stoppage', 'Miscontrol',
#        'Goal Keeper', 'Player Off', 'Player On', 'Offside', '50/50',
#        'Half End', 'Substitution', 'Tactical Shift', 'Bad Behaviour'],
#       dtype=object)

# %%
passes = df[df['type_name']=='Pass']
passes
# Out:
#                                         id  index  period        timestamp  \
# 9     5ba6dfab-49f0-4225-bbb6-8b1e27bc729a     10       1  00:00:16.423000
# 15    27829865-a43c-4c50-b545-b09e8a965e16     16       1  00:00:31.843000
# 18    59420b0c-94cc-4fb8-86fb-e1105936f6eb     19       1  00:00:34.727000
# 21    71cb648d-11fe-4275-b838-cbcfc62bee04     22       1  00:00:39.227000
# 24    4fd86774-8f37-4ea2-b562-b1a43c5adedf     25       1  00:00:43.285000
# ...                                    ...    ...     ...              ...
# 4347  dab75a96-34a0-4c95-9b3f-f45d06c41ec6   4348       4  00:17:51.942000
# 4350  494f058f-f207-4eaf-8572-fa8231480ea1   4351       4  00:17:54.818000
# 4354  fc143837-ac4c-4606-84d0-8d4d2c4c1f22   4355       4  00:17:58.777000
# 4359  2c132bb4-b135-420e-9cf3-a1ed869bc2a9   4360       4  00:18:39.985000
# 4361  641f3cd8-283d-4fa9-ac2f-d6c3a22afae3   4362       4  00:18:42.130000
#
#       minute  second  possession  duration  match_id  type_id  ...  \
# 9          0      16           3  1.123351   3869685       30  ...
# 15         0      31           4  1.660349   3869685       30  ...
# 18         0      34           4  1.814283   3869685       30  ...
# 21         0      39           4  1.121537   3869685       30  ...
# 24         0      43           4  1.586917   3869685       30  ...
# ...      ...     ...         ...       ...       ...      ...  ...
# 4347     122      51         246  0.862652   3869685       30  ...
# 4350     122      54         246  2.847939   3869685       30  ...
# 4354     122      58         246  1.057331   3869685       30  ...
# 4359     123      39         247  0.740403   3869685       30  ...
# 4361     123      42         247  0.736452   3869685       30  ...
#
#      foul_committed_card_id  foul_committed_card_name ball_recovery_offensive  \
# 9                       NaN                       NaN                     NaN
# 15                      NaN                       NaN                     NaN
# 18                      NaN                       NaN                     NaN
# 21                      NaN                       NaN                     NaN
# 24                      NaN                       NaN                     NaN
# ...                     ...                       ...                     ...
# 4347                    NaN                       NaN                     NaN
# 4350                    NaN                       NaN                     NaN
# 4354                    NaN                       NaN                     NaN
# 4359                    NaN                       NaN                     NaN
# 4361                    NaN                       NaN                     NaN
#
#       shot_one_on_one foul_committed_advantage  foul_won_advantage  \
# 9                 NaN                      NaN                 NaN
# 15                NaN                      NaN                 NaN
# 18                NaN                      NaN                 NaN
# 21                NaN                      NaN                 NaN
# 24                NaN                      NaN                 NaN
# ...               ...                      ...                 ...
# 4347              NaN                      NaN                 NaN
# 4350              NaN                      NaN                 NaN
# 4354              NaN                      NaN                 NaN
# 4359              NaN                      NaN                 NaN
# 4361              NaN                      NaN                 NaN
#
#      block_offensive foul_committed_offensive  bad_behaviour_card_id  \
# 9                NaN                      NaN                    NaN
# 15               NaN                      NaN                    NaN
# 18               NaN                      NaN                    NaN
# 21               NaN                      NaN                    NaN
# 24               NaN                      NaN                    NaN
# ...              ...                      ...                    ...
# 4347             NaN                      NaN                    NaN
# 4350             NaN                      NaN                    NaN
# 4354             NaN                      NaN                    NaN
# 4359             NaN                      NaN                    NaN
# 4361             NaN                      NaN                    NaN
#
#      bad_behaviour_card_name
# 9                        NaN
# 15                       NaN
# 18                       NaN
# 21                       NaN
# 24                       NaN
# ...                      ...
# 4347                     NaN
# 4350                     NaN
# 4354                     NaN
# 4359                     NaN
# 4361                     NaN
#
# [693 rows x 76 columns]

# %%
passes = passes[['id','minute','player_id','player_name','x','y','end_x', 'end_y','pass_recipient_id','pass_recipient_name','outcome_id','outcome_name']]

# %%
passes
# Out:
#                                         id  minute  player_id  \
# 9     5ba6dfab-49f0-4225-bbb6-8b1e27bc729a       0    29201.0
# 15    27829865-a43c-4c50-b545-b09e8a965e16       0     7797.0
# 18    59420b0c-94cc-4fb8-86fb-e1105936f6eb       0    20572.0
# 21    71cb648d-11fe-4275-b838-cbcfc62bee04       0     3090.0
# 24    4fd86774-8f37-4ea2-b562-b1a43c5adedf       0    20572.0
# ...                                    ...     ...        ...
# 4347  dab75a96-34a0-4c95-9b3f-f45d06c41ec6     122    38718.0
# 4350  494f058f-f207-4eaf-8572-fa8231480ea1     122     5503.0
# 4354  fc143837-ac4c-4606-84d0-8d4d2c4c1f22     122    28263.0
# 4359  2c132bb4-b135-420e-9cf3-a1ed869bc2a9     123    19597.0
# 4361  641f3cd8-283d-4fa9-ac2f-d6c3a22afae3     123    16308.0
#
#                          player_name      x     y  end_x  end_y  \
# 9               Nahuel Molina Lucero   22.7  80.0   36.0   75.2
# 15            Rodrigo Javier De Paul   41.1  73.9   23.2   62.8
# 18           Cristian Gabriel Romero   24.7  59.4   21.5   32.2
# 21           Nicolás Hernán Otamendi   24.0  27.1   21.7   49.3
# 24           Cristian Gabriel Romero   22.1  49.8   24.0   27.3
# ...                              ...    ...   ...    ...    ...
# 4347                  Enzo Fernandez   42.8  54.1   58.0   62.4
# 4350  Lionel Andrés Messi Cuccittini   66.8  62.6  104.9   62.6
# 4354           Gonzalo Ariel Montiel  109.3  61.6  110.8   41.6
# 4359             Marcos Javier Acuña   46.5  20.1   62.5   25.8
# 4361          Leandro Daniel Paredes   47.1  27.3   56.1   22.0
#
#       pass_recipient_id             pass_recipient_name  outcome_id  \
# 9                7797.0          Rodrigo Javier De Paul         NaN
# 15              20572.0         Cristian Gabriel Romero         NaN
# 18               3090.0         Nicolás Hernán Otamendi         NaN
# 21              20572.0         Cristian Gabriel Romero         NaN
# 24               3090.0         Nicolás Hernán Otamendi         NaN
# ...                 ...                             ...         ...
# 4347             5503.0  Lionel Andrés Messi Cuccittini         NaN
# 4350            28263.0           Gonzalo Ariel Montiel         NaN
# 4354            11456.0         Lautaro Javier Martínez         NaN
# 4359                NaN                             NaN         9.0
# 4361            38718.0                  Enzo Fernandez         NaN
#
#      outcome_name
# 9             NaN
# 15            NaN
# 18            NaN
# 21            NaN
# 24            NaN
# ...           ...
# 4347          NaN
# 4350          NaN
# 4354          NaN
# 4359   Incomplete
# 4361          NaN
#
# [693 rows x 12 columns]

# %%
passes['outcome_name'].unique()
# Out:
# array([nan, 'Incomplete', 'Pass Offside', 'Unknown', 'Out'], dtype=object)

# %%
successful = passes[passes['outcome_name'].isnull()]
successful
# Out:
#                                         id  minute  player_id  \
# 9     5ba6dfab-49f0-4225-bbb6-8b1e27bc729a       0    29201.0
# 15    27829865-a43c-4c50-b545-b09e8a965e16       0     7797.0
# 18    59420b0c-94cc-4fb8-86fb-e1105936f6eb       0    20572.0
# 21    71cb648d-11fe-4275-b838-cbcfc62bee04       0     3090.0
# 24    4fd86774-8f37-4ea2-b562-b1a43c5adedf       0    20572.0
# ...                                    ...     ...        ...
# 4344  1bd05b73-2c69-455f-a9af-1820fbef4f31     122     5743.0
# 4347  dab75a96-34a0-4c95-9b3f-f45d06c41ec6     122    38718.0
# 4350  494f058f-f207-4eaf-8572-fa8231480ea1     122     5503.0
# 4354  fc143837-ac4c-4606-84d0-8d4d2c4c1f22     122    28263.0
# 4361  641f3cd8-283d-4fa9-ac2f-d6c3a22afae3     123    16308.0
#
#                          player_name      x     y  end_x  end_y  \
# 9               Nahuel Molina Lucero   22.7  80.0   36.0   75.2
# 15            Rodrigo Javier De Paul   41.1  73.9   23.2   62.8
# 18           Cristian Gabriel Romero   24.7  59.4   21.5   32.2
# 21           Nicolás Hernán Otamendi   24.0  27.1   21.7   49.3
# 24           Cristian Gabriel Romero   22.1  49.8   24.0   27.3
# ...                              ...    ...   ...    ...    ...
# 4344     Paulo Bruno Exequiel Dybala   44.3  48.3   42.8   54.1
# 4347                  Enzo Fernandez   42.8  54.1   58.0   62.4
# 4350  Lionel Andrés Messi Cuccittini   66.8  62.6  104.9   62.6
# 4354           Gonzalo Ariel Montiel  109.3  61.6  110.8   41.6
# 4361          Leandro Daniel Paredes   47.1  27.3   56.1   22.0
#
#       pass_recipient_id             pass_recipient_name  outcome_id  \
# 9                7797.0          Rodrigo Javier De Paul         NaN
# 15              20572.0         Cristian Gabriel Romero         NaN
# 18               3090.0         Nicolás Hernán Otamendi         NaN
# 21              20572.0         Cristian Gabriel Romero         NaN
# 24               3090.0         Nicolás Hernán Otamendi         NaN
# ...                 ...                             ...         ...
# 4344            38718.0                  Enzo Fernandez         NaN
# 4347             5503.0  Lionel Andrés Messi Cuccittini         NaN
# 4350            28263.0           Gonzalo Ariel Montiel         NaN
# 4354            11456.0         Lautaro Javier Martínez         NaN
# 4361            38718.0                  Enzo Fernandez         NaN
#
#      outcome_name
# 9             NaN
# 15            NaN
# 18            NaN
# 21            NaN
# 24            NaN
# ...           ...
# 4344          NaN
# 4347          NaN
# 4350          NaN
# 4354          NaN
# 4361          NaN
#
# [560 rows x 12 columns]

# %%
subs = df[df['type_name']=='Substitution']
subs = subs['minute']
firstSub= subs.min()
firstSub
# Out:
# 63

# %%
successful = successful[successful['minute']<firstSub]
successful
# Out:
#                                         id  minute  player_id  \
# 9     5ba6dfab-49f0-4225-bbb6-8b1e27bc729a       0    29201.0
# 15    27829865-a43c-4c50-b545-b09e8a965e16       0     7797.0
# 18    59420b0c-94cc-4fb8-86fb-e1105936f6eb       0    20572.0
# 21    71cb648d-11fe-4275-b838-cbcfc62bee04       0     3090.0
# 24    4fd86774-8f37-4ea2-b562-b1a43c5adedf       0    20572.0
# ...                                    ...     ...        ...
# 2250  01d9ee95-3444-4531-8d7c-6d9aaea38af4      61     7797.0
# 2253  d9decd31-b9de-440a-87cb-6b58031b8710      61    29201.0
# 2255  2cb0384f-82dd-4e79-8c8a-3aeee4a8e1ac      61    38718.0
# 2307  2e853ebf-ded0-4b62-a149-1f579210d42e      62    27886.0
# 2310  02c095d9-dddd-49f1-b9f6-472ad211ad9f      62     5503.0
#
#                          player_name     x     y  end_x  end_y  \
# 9               Nahuel Molina Lucero  22.7  80.0   36.0   75.2
# 15            Rodrigo Javier De Paul  41.1  73.9   23.2   62.8
# 18           Cristian Gabriel Romero  24.7  59.4   21.5   32.2
# 21           Nicolás Hernán Otamendi  24.0  27.1   21.7   49.3
# 24           Cristian Gabriel Romero  22.1  49.8   24.0   27.3
# ...                              ...   ...   ...    ...    ...
# 2250          Rodrigo Javier De Paul  46.5  73.3   37.3   77.6
# 2253            Nahuel Molina Lucero  37.3  77.6   37.0   69.0
# 2255                  Enzo Fernandez  36.4  69.3   46.5   75.5
# 2307             Alexis Mac Allister  57.8  35.5   57.8   45.5
# 2310  Lionel Andrés Messi Cuccittini  64.0  43.4   90.5   25.8
#
#       pass_recipient_id             pass_recipient_name  outcome_id  \
# 9                7797.0          Rodrigo Javier De Paul         NaN
# 15              20572.0         Cristian Gabriel Romero         NaN
# 18               3090.0         Nicolás Hernán Otamendi         NaN
# 21              20572.0         Cristian Gabriel Romero         NaN
# 24               3090.0         Nicolás Hernán Otamendi         NaN
# ...                 ...                             ...         ...
# 2250            29201.0            Nahuel Molina Lucero         NaN
# 2253            38718.0                  Enzo Fernandez         NaN
# 2255             7797.0          Rodrigo Javier De Paul         NaN
# 2307             5503.0  Lionel Andrés Messi Cuccittini         NaN
# 2310            29560.0                  Julián Álvarez         NaN
#
#      outcome_name
# 9             NaN
# 15            NaN
# 18            NaN
# 21            NaN
# 24            NaN
# ...           ...
# 2250          NaN
# 2253          NaN
# 2255          NaN
# 2307          NaN
# 2310          NaN
#
# [317 rows x 12 columns]

# %%
df_lineup = parser.lineup(3869685)
jersey_data =df_lineup[['player_id','jersey_number']]
jersey_data
# Out:
#     player_id  jersey_number
# 0        2972             26
# 1        3009             10
# 2        3026             14
# 3        3099              1
# 4        3379             23
# 5        3543             16
# 6        3604              9
# 7        4445              5
# 8        5476              2
# 9        5477             11
# 10       5485              4
# 11       5487              7
# 12       6704             22
# 13       7153             15
# 14       7345              6
# 15       7439              3
# 16       8217             20
# 17       8519             18
# 18      10481              8
# 19      11135             24
# 20      11990             13
# 21      17592             17
# 22      22097             12
# 23      24778             25
# 24       2995             11
# 25       3090             19
# 26       5503             10
# 27       5507              3
# 28       5743             21
# 29       6312              1
# 30       6377             15
# 31       6694             12
# 32       6909             23
# 33       7006             17
# 34       7161              6
# 35       7797              7
# 36      11456             22
# 37      16308              5
# 38      19597              8
# 39      20572             13
# 40      21081              2
# 41      26404             18
# 42      27768             25
# 43      27886             20
# 44      28263              4
# 45      28268             14
# 46      28637             16
# 47      29201             26
# 48      29560              9
# 49      38718             24

# %%
successful = pd.merge(successful,jersey_data,on='player_id')
successful.rename(columns={'jersey_number':'passer'},inplace=True)
successful
# Out:
#                                        id  minute  player_id  \
# 0    5ba6dfab-49f0-4225-bbb6-8b1e27bc729a       0    29201.0
# 1    1bbd0ed6-cf44-46ce-b20d-a8f09ae3aed3      11    29201.0
# 2    797e26ff-2184-4b02-8c89-71127107b9d3      14    29201.0
# 3    c485f3d6-53dc-4d64-8b4a-14fbc1c6a597      19    29201.0
# 4    adcfd088-5a4c-4385-8941-d6f08c783607      20    29201.0
# ..                                    ...     ...        ...
# 312  40f400c2-2be9-4210-94d3-9108fec7be8d      48     6909.0
# 313  9b2ea230-1c90-47a8-81ec-74444987719a      49     6909.0
# 314  a9531b08-62b5-43b4-8978-8ad1e417716c      50     6909.0
# 315  0576f719-69d3-4f8a-a2f3-2646985ef4de      51     6909.0
# 316  2a574c4f-312b-4e31-a41e-56ce4c6742f3      53     6909.0
#
#                   player_name     x     y  end_x  end_y  pass_recipient_id  \
# 0        Nahuel Molina Lucero  22.7  80.0   36.0   75.2             7797.0
# 1        Nahuel Molina Lucero  67.0  60.9   64.7   49.3            38718.0
# 2        Nahuel Molina Lucero  68.1  72.4   47.3   61.8            20572.0
# 3        Nahuel Molina Lucero  50.1  75.2   41.6   62.4             7797.0
# 4        Nahuel Molina Lucero  94.4  74.8   74.5   69.7             7797.0
# ..                        ...   ...   ...    ...    ...                ...
# 312  Damián Emiliano Martínez  18.9  48.1   22.1   23.0             3090.0
# 313  Damián Emiliano Martínez   2.8  56.6   20.8   74.6            29201.0
# 314  Damián Emiliano Martínez  15.0  54.3   25.5   25.4             3090.0
# 315  Damián Emiliano Martínez  15.4  46.2   36.0   75.7             2995.0
# 316  Damián Emiliano Martínez  34.3  30.3   39.4   35.0            38718.0
#
#                  pass_recipient_name  outcome_id outcome_name  passer
# 0             Rodrigo Javier De Paul         NaN          NaN      26
# 1                     Enzo Fernandez         NaN          NaN      26
# 2            Cristian Gabriel Romero         NaN          NaN      26
# 3             Rodrigo Javier De Paul         NaN          NaN      26
# 4             Rodrigo Javier De Paul         NaN          NaN      26
# ..                               ...         ...          ...     ...
# 312          Nicolás Hernán Otamendi         NaN          NaN      23
# 313             Nahuel Molina Lucero         NaN          NaN      23
# 314          Nicolás Hernán Otamendi         NaN          NaN      23
# 315  Ángel Fabián Di María Hernández         NaN          NaN      23
# 316                   Enzo Fernandez         NaN          NaN      23
#
# [317 rows x 13 columns]

# %%
jersey_data.rename(columns={'player_id':'pass_recipient_id'},inplace=True)
successful = pd.merge(successful,jersey_data,on='pass_recipient_id')
successful.rename(columns={'jersey_number':'recipient'},inplace=True)
successful
# Out:
# C:\Users\lamsa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                                        id  minute  player_id  \
# 0    5ba6dfab-49f0-4225-bbb6-8b1e27bc729a       0    29201.0
# 1    c485f3d6-53dc-4d64-8b4a-14fbc1c6a597      19    29201.0
# 2    adcfd088-5a4c-4385-8941-d6f08c783607      20    29201.0
# 3    52a1186a-ffa4-46e3-95f1-0d0040c0308c      33    29201.0
# 4    c25f437a-83a8-4bdf-8989-ad5d946bab6c      33    29201.0
# ..                                    ...     ...        ...
# 312  a4f710ab-eee8-4336-9fcc-55549e52c9b4       4     2995.0
# 313  e9446c3a-2390-4a76-bde6-547d5c99f171      11     2995.0
# 314  cba89f29-2e13-411d-aec1-ff595a43b9a7      14     2995.0
# 315  4cb4f68a-e73b-4489-a6e2-23a5bec0f905      15     2995.0
# 316  570c85b3-2b70-43db-9891-90f117a3132d      45     2995.0
#
#                          player_name     x     y  end_x  end_y  \
# 0               Nahuel Molina Lucero  22.7  80.0   36.0   75.2
# 1               Nahuel Molina Lucero  50.1  75.2   41.6   62.4
# 2               Nahuel Molina Lucero  94.4  74.8   74.5   69.7
# 3               Nahuel Molina Lucero  35.6  72.9   43.7   66.2
# 4               Nahuel Molina Lucero  81.3  73.3   67.0   71.8
# ..                               ...   ...   ...    ...    ...
# 312  Ángel Fabián Di María Hernández  89.5   3.4   82.4    7.4
# 313  Ángel Fabián Di María Hernández  43.9   2.7   31.1    5.3
# 314  Ángel Fabián Di María Hernández  76.4   6.8   55.7    4.9
# 315  Ángel Fabián Di María Hernández  76.2   2.3   62.5    5.3
# 316  Ángel Fabián Di María Hernández  57.6   4.0   39.8    5.9
#
#      pass_recipient_id           pass_recipient_name  outcome_id outcome_name  \
# 0               7797.0        Rodrigo Javier De Paul         NaN          NaN
# 1               7797.0        Rodrigo Javier De Paul         NaN          NaN
# 2               7797.0        Rodrigo Javier De Paul         NaN          NaN
# 3               7797.0        Rodrigo Javier De Paul         NaN          NaN
# 4               7797.0        Rodrigo Javier De Paul         NaN          NaN
# ..                 ...                           ...         ...          ...
# 312             5507.0  Nicolás Alejandro Tagliafico         NaN          NaN
# 313             5507.0  Nicolás Alejandro Tagliafico         NaN          NaN
# 314             5507.0  Nicolás Alejandro Tagliafico         NaN          NaN
# 315             5507.0  Nicolás Alejandro Tagliafico         NaN          NaN
# 316             5507.0  Nicolás Alejandro Tagliafico         NaN          NaN
#
#      passer  recipient
# 0        26          7
# 1        26          7
# 2        26          7
# 3        26          7
# 4        26          7
# ..      ...        ...
# 312      11          3
# 313      11          3
# 314      11          3
# 315      11          3
# 316      11          3
#
# [317 rows x 14 columns]

# %%
average_locations = successful.groupby('passer').agg({'x':['mean'],'y':['mean','count']})

# %%
average_locations.columns = ['x','y','count']
average_locations
# Out:
#                 x          y  count
# passer
# 3       58.567857   7.335714     28
# 7       59.159459  59.248649     37
# 9       76.346154  37.538462     13
# 10      71.588889  51.096296     27
# 11      79.884000  11.448000     25
# 13      33.905128  53.346154     39
# 19      38.279545  23.350000     44
# 20      68.737500  23.845833     24
# 23      12.641667  43.966667     12
# 24      56.135000  36.532500     40
# 26      59.414286  72.085714     28

# %%
pass_between = successful.groupby(['passer','recipient']).id.count().reset_index()
pass_between.rename(columns={'id':'pass_count'},inplace=True)
pass_between
# Out:
#     passer  recipient  pass_count
# 0        3          9           1
# 1        3         11           7
# 2        3         19           7
# 3        3         20           9
# 4        3         24           4
# ..     ...        ...         ...
# 72      26         13           1
# 73      26         19           1
# 74      26         20           1
# 75      26         23           2
# 76      26         24           2
#
# [77 rows x 3 columns]

# %%
pass_between = pd.merge(pass_between, average_locations,on='passer')
pass_between
# Out:
#     passer  recipient  pass_count          x          y  count
# 0        3          9           1  58.567857   7.335714     28
# 1        3         11           7  58.567857   7.335714     28
# 2        3         19           7  58.567857   7.335714     28
# 3        3         20           9  58.567857   7.335714     28
# 4        3         24           4  58.567857   7.335714     28
# ..     ...        ...         ...        ...        ...    ...
# 72      26         13           1  59.414286  72.085714     28
# 73      26         19           1  59.414286  72.085714     28
# 74      26         20           1  59.414286  72.085714     28
# 75      26         23           2  59.414286  72.085714     28
# 76      26         24           2  59.414286  72.085714     28
#
# [77 rows x 6 columns]

# %%
average_locations=average_locations.rename_axis('recipient')
pass_between = pd.merge(pass_between, average_locations,on='recipient',suffixes=['','_end'])
pass_between
# Out:
#     passer  recipient  pass_count          x          y  count      x_end  \
# 0        3          9           1  58.567857   7.335714     28  76.346154
# 1        7          9           1  59.159459  59.248649     37  76.346154
# 2       10          9           4  71.588889  51.096296     27  76.346154
# 3       11          9           2  79.884000  11.448000     25  76.346154
# 4       13          9           1  33.905128  53.346154     39  76.346154
# ..     ...        ...         ...        ...        ...    ...        ...
# 72      26          7          13  59.414286  72.085714     28  59.159459
# 73      11          3           5  79.884000  11.448000     25  58.567857
# 74      19          3          11  38.279545  23.350000     44  58.567857
# 75      20          3           3  68.737500  23.845833     24  58.567857
# 76      24          3           4  56.135000  36.532500     40  58.567857
#
#         y_end  count_end
# 0   37.538462         13
# 1   37.538462         13
# 2   37.538462         13
# 3   37.538462         13
# 4   37.538462         13
# ..        ...        ...
# 72  59.248649         37
# 73   7.335714         28
# 74   7.335714         28
# 75   7.335714         28
# 76   7.335714         28
#
# [77 rows x 9 columns]

# %%
pass_between = pass_between[pass_between['pass_count']>3]

# %%
pass_between.head()
# Out:
#     passer  recipient  pass_count          x          y  count      x_end  \
# 2       10          9           4  71.588889  51.096296     27  76.346154
# 8        3         11           7  58.567857   7.335714     28  79.884000
# 10      10         11           5  71.588889  51.096296     27  79.884000
# 12      19         11           4  38.279545  23.350000     44  79.884000
# 13      20         11           8  68.737500  23.845833     24  79.884000
#
#         y_end  count_end
# 2   37.538462         13
# 8   11.448000         25
# 10  11.448000         25
# 12  11.448000         25
# 13  11.448000         25

# %%
pitch = Pitch(pitch_color='white',line_color='#B6BBC4')

fig,ax = pitch.draw(figsize=(8,6))

#Draw arrows and nodes
arrows = pitch.arrows(1.2*pass_between.x,0.8*pass_between.y,1.2*pass_between.x_end,0.8*pass_between.y_end,ax=ax,color='red',alpha=0.4,width=3)

nodes = pitch.scatter(1.2*average_locations.x,0.8*average_locations.y,s=20*average_locations['count'].values,color='white',edgecolors='#a6aab3',linewidth=1,ax=ax)


# Put jersey number in the nodes

for index,row in average_locations.iterrows():
    pitch.annotate(index,xy=(1.2*row.x,0.8*row.y),c='#161A30', fontweight='bold',va='center',ha='center',size=8, ax=ax)

    
ax.set_title('Argentina vs France',color='red',va='center',ha='center',fontsize=12,fontweight='bold',pad=20)

ax.annotate('World Cup Final', xy=(0.5, 1), xytext=(0, 0),
             xycoords='axes fraction', textcoords='offset points',
             fontsize=10, color='#0E2954', va='top', ha='center')

ax.text(114, 85, '@samippl1', color='#0E2954', va='bottom', ha='center', fontsize=10)
plt.show()
